# %% [markdown]
# # Mathematical Underpinnings - Lab 7

# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Input, Dense, Lambda, InputLayer, concatenate
from keras.models import Model, Sequential
from keras import backend as K
from keras import metrics
from keras.datasets import mnist
from keras.utils import to_categorical

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Task 1
#
# ### a)

# %%
def KL_mult_normal(mu1, mu2, Sigma1, Sigma2):
    # the formula is here: https://statproofbook.github.io/P/mvn-kl.html
    return (np.dot(mu2-mu1, np.dot(np.linalg.inv(Sigma2), mu2 - mu1)) + np.sum(np.diag(np.dot(np.linalg.inv(Sigma2), Sigma1))) \
        - np.log(np.linalg.det(Sigma1)/np.linalg.det(Sigma2)) - mu1.shape[0])/2

# %%
def T_opt(x, mu1, mu2, Sigma1, Sigma2):
    # compute log(p(x)/q(x)), where p and q are multivariate normal with parameters mu1, Sigma1 and mu2, Sigma2 respectively
    # density of multivariate normal distribution is e.g. here: https://en.wikipedia.org/wiki/Multivariate_normal_distribution
    res = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        ft = -np.log(np.linalg.det(Sigma1))/2 - np.dot(np.dot(np.linalg.inv(Sigma1), (x[i,:] - mu1)), x[i,:] - mu1)/2
        st = np.log(np.linalg.det(Sigma2))/2 + np.dot(np.dot(np.linalg.inv(Sigma2), x[i,:] - mu2), x[i,:] - mu2)/2
        res[i] = ft+st
    return res

# %% [markdown]
# ### b)

# %%
# sample n = 10000 observations out of np.random.multivariate_normal(mu1, Sigma1, size=n)
# and sample n = 10000 observations out of np.random.multivariate_normal(mu2, Sigma2, size=n)
# then concatenate the two matrices (your final x is a matrix 2n x 5)
# then create a vector y that will have n ones and n zeros (of size 2n)

# np.random.seed(123)
n = 10000
mu1 = np.array([1, 1, 1, 0, 0])/5
mu2 = np.array([0, 0, 1, 1, 1])/5
Sigma1 = (np.eye(5)*9 + np.ones((5,5)))/10
Sigma2 = 1.2*np.eye(5) - np.ones((5,5))/5
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n)
x = np.concatenate((x1, x2), axis=0)
y = np.concatenate((1.0*np.ones(n), 0.0*np.zeros(n)))

# %%
def DV_fun(y, t):
    # y - an indicator [y[i]=1 if t[i] corresponds to x sampled from the distribution p, y[i]=0 otherwise]
    # t a vector (of the same length as y) t = log(p(x)/q(x))
    n1 = np.sum(y)
    n2 = np.sum(1 - y)
    return np.sum(t*y)/n1 - np.log(np.sum(np.exp(t)*(1-y))/n2)

# %%
KL_mult_normal(mu1, mu2, Sigma1, Sigma2)
# Out:
# 2.169075737042572

# %%
DV_fun(y, T_opt(x, mu1, mu2, Sigma1, Sigma2))
# Out:
# 2.2135321228995317

# %%
# 18:56

# %% [markdown]
# ### c)

# %%
def DV_loss(y_true, T_x):
    n1 = tf.math.reduce_sum(y_true)
    n2 = tf.math.reduce_sum(tf.subtract(tf.convert_to_tensor(1.0), y_true))
    first_term = tf.math.reduce_sum(tf.math.multiply(T_x, y_true))/n1
    second_term = tf.math.log(tf.math.reduce_sum(tf.math.multiply(tf.math.exp(T_x), tf.subtract(tf.convert_to_tensor(1.0), y_true)))/n2)
    return -(first_term - second_term)

# %% [markdown]
# ### d)

# %%
model_inputs = keras.Input(shape=(5))
layer_out = Dense(64, activation='softplus')(model_inputs)
#layer_out = Dense(125, activation='tanh')(layer_out)
layer_out = Dense(64)(layer_out)
model_outputs = Dense(1)(layer_out)
model = keras.Model(model_inputs, model_outputs)

optimizer = keras.optimizers.SGD(learning_rate=1e-2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=optimizer, loss=DV_loss)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
hist = model.fit(x_train, y_train, epochs=100, batch_size=1024, validation_data=(x_test, y_test), callbacks=[es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 20ms/step - loss: -0.0047 - val_loss: -0.0105
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0411 - val_loss: -0.0347
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0609 - val_loss: -0.0480
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0716 - val_loss: -0.0559
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0787 - val_loss: -0.0606
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0826 - val_loss: -0.0640
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0854 - val_loss: -0.0665
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0881 - val_loss: -0.0686
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0905 - val_loss: -0.0706
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0924 - val_loss: -0.0724
# Epoch 11/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0944 - val_loss: -0.0742
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0963 - val_loss: -0.0761
# Epoch 13/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0983 - val_loss: -0.0782
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1000 - val_loss: -0.0800
# Epoch 15/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.1021 - val_loss: -0.0821
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1043 - val_loss: -0.0843
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1065 - val_loss: -0.0865
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1085 - val_loss: -0.0888
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1110 - val_loss: -0.0908
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1131 - val_loss: -0.0929
# Epoch 21/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1156 - val_loss: -0.0953
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1182 - val_loss: -0.0979
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1211 - val_loss: -0.1006
# Epoch 24/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1232 - val_loss: -0.1034
# Epoch 25/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1262 - val_loss: -0.1063
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1291 - val_loss: -0.1094
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1322 - val_loss: -0.1125
# Epoch 28/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1358 - val_loss: -0.1158
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1390 - val_loss: -0.1193
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1428 - val_loss: -0.1230
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1465 - val_loss: -0.1270
# Epoch 32/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1504 - val_loss: -0.1312
# Epoch 33/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1547 - val_loss: -0.1359
# Epoch 34/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1595 - val_loss: -0.1407
# Epoch 35/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.1644 - val_loss: -0.1458
# Epoch 36/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1693 - val_loss: -0.1516
# Epoch 37/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1748 - val_loss: -0.1577
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1813 - val_loss: -0.1643
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1879 - val_loss: -0.1716
# Epoch 40/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1950 - val_loss: -0.1790
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2027 - val_loss: -0.1872
# Epoch 42/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2115 - val_loss: -0.1963
# Epoch 43/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2202 - val_loss: -0.2066
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2307 - val_loss: -0.2178
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2422 - val_loss: -0.2300
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2544 - val_loss: -0.2441
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2689 - val_loss: -0.2594
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2840 - val_loss: -0.2761
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3013 - val_loss: -0.2952
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3208 - val_loss: -0.3173
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3431 - val_loss: -0.3419
# Epoch 52/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3678 - val_loss: -0.3692
# Epoch 53/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.3966 - val_loss: -0.4016
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.4292 - val_loss: -0.4387
# Epoch 55/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.4676 - val_loss: -0.4813
# Epoch 56/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.5116 - val_loss: -0.5315
# Epoch 57/100
# 15/15 [==============================] - 0s 10ms/step - loss: -0.5621 - val_loss: -0.5891
# Epoch 58/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.6213 - val_loss: -0.6571
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.6916 - val_loss: -0.7368
# Epoch 60/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.7755 - val_loss: -0.8336
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.8739 - val_loss: -0.9454
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.9895 - val_loss: -1.0792
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.1252 - val_loss: -1.2341
# Epoch 64/100
# 15/15 [==============================] - 0s 8ms/step - loss: -1.2827 - val_loss: -1.4095
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.4589 - val_loss: -1.6011
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.6478 - val_loss: -1.7948
# Epoch 67/100
# 15/15 [==============================] - 0s 7ms/step - loss: -1.8228 - val_loss: -1.9649
# Epoch 68/100
# 15/15 [==============================] - 0s 7ms/step - loss: -1.9652 - val_loss: -2.0311
# Epoch 69/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.0420 - val_loss: -2.0832
# Epoch 70/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.1008 - val_loss: -2.1934
# Epoch 71/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1546 - val_loss: -1.9765
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1808 - val_loss: -2.2277
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1495 - val_loss: -2.1916
# Epoch 74/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.1921 - val_loss: -2.1808
# Epoch 75/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1428 - val_loss: -2.1458
# Epoch 76/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.1211 - val_loss: -2.0919
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1978 - val_loss: -2.1221
# Epoch 77: early stopping

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.show()

# %% [markdown]
# ### e)

# %%
t_x_pred = model.predict(x)[:,0]
# Out:
# 625/625 [==============================] - 1s 2ms/step

# %%
t_x_opt = T_opt(x, mu1, mu2, Sigma1, Sigma2)

# %%
plt.plot(t_x_opt)
plt.plot(t_x_pred)

plt.show()

# %%
plt.plot(t_x_pred[y==1], t_x_opt[y==1], "o", alpha=0.2, markersize=2)
plt.plot(t_x_pred[y==0], t_x_opt[y==0], "o", alpha=0.2, markersize=2)
plt.grid()
plt.show()

# %%
plt.plot(t_x_pred, t_x_opt, "o")
plt.show()

# %%
DV_fun(y, t_x_pred)
# Out:
# 2.0351212198310504

# %%
DV_fun(y, t_x_opt)
# Out:
# 2.2135321228995317

# %%
# new data
n_new = 10000
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n_new)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n_new)
x_new = np.concatenate((x1, x2), axis=0)
y_new = np.concatenate((1.0*np.ones(n_new), 0.0*np.zeros(n_new)))

# %%
t_x_pred = model.predict(x_new)
t_x_pred = t_x_pred[:,0]
# Out:
# 625/625 [==============================] - 1s 2ms/step

# %%
t_x_opt = T_opt(x_new, mu1, mu2, Sigma1, Sigma2)

# %%
DV_fun(y_new, t_x_pred)
# Out:
# 2.138602601447685

# %%
DV_fun(y_new, t_x_opt)
# Out:
# 2.3224675074061594

# %% [markdown]
# ### f)

# %%
# def NWJ_loss(y_true, y_pred):
#     pass

# %%
# HOMEWORK - just f)
