# %% [markdown]
# # Mathematical Underpinnings - Lab 7

# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Input, Dense, Lambda, InputLayer, concatenate
from keras.models import Model, Sequential
from keras import backend as K
from keras import metrics
from keras.datasets import mnist
from keras.utils import to_categorical

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Task 1
#
# ### a)

# %%
def KL_mult_normal(mu1, mu2, Sigma1, Sigma2):
    # the formula is here: https://statproofbook.github.io/P/mvn-kl.html
    return (np.dot(mu2-mu1, np.dot(np.linalg.inv(Sigma2), mu2 - mu1)) + np.sum(np.diag(np.dot(np.linalg.inv(Sigma2), Sigma1))) \
        - np.log(np.linalg.det(Sigma1)/np.linalg.det(Sigma2)) - mu1.shape[0])/2

# %%
def T_opt(x, mu1, mu2, Sigma1, Sigma2):
    # compute log(p(x)/q(x)), where p and q are multivariate normal with parameters mu1, Sigma1 and mu2, Sigma2 respectively
    # density of multivariate normal distribution is e.g. here: https://en.wikipedia.org/wiki/Multivariate_normal_distribution
    res = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        ft = -np.log(np.linalg.det(Sigma1))/2 - np.dot(np.dot(np.linalg.inv(Sigma1), (x[i,:] - mu1)), x[i,:] - mu1)/2
        st = np.log(np.linalg.det(Sigma2))/2 + np.dot(np.dot(np.linalg.inv(Sigma2), x[i,:] - mu2), x[i,:] - mu2)/2
        res[i] = ft+st
    return res

# %% [markdown]
# ### b)

# %%
# sample n = 10000 observations out of np.random.multivariate_normal(mu1, Sigma1, size=n)
# and sample n = 10000 observations out of np.random.multivariate_normal(mu2, Sigma2, size=n)
# then concatenate the two matrices (your final x is a matrix 2n x 5)
# then create a vector y that will have n ones and n zeros (of size 2n)

# np.random.seed(123)
n = 10000
mu1 = np.array([1, 1, 1, 0, 0])/5
mu2 = np.array([0, 0, 1, 1, 1])/5
Sigma1 = (np.eye(5)*9 + np.ones((5,5)))/10
Sigma2 = 1.2*np.eye(5) - np.ones((5,5))/5
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n)
x = np.concatenate((x1, x2), axis=0)
y = np.concatenate((1.0*np.ones(n), 0.0*np.zeros(n)))

# %%
def DV_fun(y, t):
    # y - an indicator [y[i]=1 if t[i] corresponds to x sampled from the distribution p, y[i]=0 otherwise]
    # t a vector (of the same length as y) t = log(p(x)/q(x))
    n1 = np.sum(y)
    n2 = np.sum(1 - y)
    return np.sum(t*y)/n1 - np.log(np.sum(np.exp(t)*(1-y))/n2)

# %%
KL_mult_normal(mu1, mu2, Sigma1, Sigma2)
# Out:
# 2.169075737042572

# %%
DV_fun(y, T_opt(x, mu1, mu2, Sigma1, Sigma2))
# Out:
# 2.3049447052510614

# %%
# 18:56

# %% [markdown]
# ### c)

# %%
def DV_loss(y_true, T_x):
    n1 = tf.math.reduce_sum(y_true)
    n2 = tf.math.reduce_sum(tf.subtract(tf.convert_to_tensor(1.0), y_true))
    first_term = tf.math.reduce_sum(tf.math.multiply(T_x, y_true))/n1
    second_term = tf.math.log(tf.math.reduce_sum(tf.math.multiply(tf.math.exp(T_x), tf.subtract(tf.convert_to_tensor(1.0), y_true)))/n2)
    return -(first_term - second_term)

# %% [markdown]
# ### d)

# %%
model_inputs = keras.Input(shape=(5))
layer_out = Dense(64, activation='softplus')(model_inputs)
#layer_out = Dense(125, activation='tanh')(layer_out)
layer_out = Dense(64)(layer_out)
model_outputs = Dense(1)(layer_out)
model = keras.Model(model_inputs, model_outputs)

optimizer = keras.optimizers.SGD(learning_rate=1e-2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=optimizer, loss=DV_loss)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
hist = model.fit(x_train, y_train, epochs=100, batch_size=1024, validation_data=(x_test, y_test), callbacks=[es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 18ms/step - loss: 0.0328 - val_loss: -0.0142
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0291 - val_loss: -0.0512
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0594 - val_loss: -0.0701
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0757 - val_loss: -0.0794
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0848 - val_loss: -0.0848
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0903 - val_loss: -0.0882
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0941 - val_loss: -0.0911
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0972 - val_loss: -0.0937
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1005 - val_loss: -0.0963
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1034 - val_loss: -0.0988
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1060 - val_loss: -0.1015
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1092 - val_loss: -0.1042
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1120 - val_loss: -0.1070
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1150 - val_loss: -0.1101
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1184 - val_loss: -0.1131
# Epoch 16/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1216 - val_loss: -0.1166
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1253 - val_loss: -0.1201
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1291 - val_loss: -0.1240
# Epoch 19/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1333 - val_loss: -0.1280
# Epoch 20/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1373 - val_loss: -0.1319
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1418 - val_loss: -0.1369
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1467 - val_loss: -0.1419
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1525 - val_loss: -0.1474
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1581 - val_loss: -0.1527
# Epoch 25/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1636 - val_loss: -0.1590
# Epoch 26/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.1706 - val_loss: -0.1659
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1780 - val_loss: -0.1734
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1861 - val_loss: -0.1818
# Epoch 29/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1950 - val_loss: -0.1906
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.2047 - val_loss: -0.2007
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2159 - val_loss: -0.2121
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2281 - val_loss: -0.2248
# Epoch 33/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2419 - val_loss: -0.2388
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2578 - val_loss: -0.2545
# Epoch 35/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2752 - val_loss: -0.2730
# Epoch 36/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2948 - val_loss: -0.2938
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3180 - val_loss: -0.3173
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3444 - val_loss: -0.3444
# Epoch 39/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.3746 - val_loss: -0.3764
# Epoch 40/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.4099 - val_loss: -0.4132
# Epoch 41/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.4507 - val_loss: -0.4561
# Epoch 42/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.4994 - val_loss: -0.5086
# Epoch 43/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.5569 - val_loss: -0.5695
# Epoch 44/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.6256 - val_loss: -0.6421
# Epoch 45/100
# 15/15 [==============================] - 0s 12ms/step - loss: -0.7076 - val_loss: -0.7287
# Epoch 46/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.8049 - val_loss: -0.8326
# Epoch 47/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.9215 - val_loss: -0.9578
# Epoch 48/100
# 15/15 [==============================] - 0s 8ms/step - loss: -1.0589 - val_loss: -1.1048
# Epoch 49/100
# 15/15 [==============================] - 0s 8ms/step - loss: -1.2214 - val_loss: -1.2758
# Epoch 50/100
# 15/15 [==============================] - 0s 8ms/step - loss: -1.4052 - val_loss: -1.4605
# Epoch 51/100
# 15/15 [==============================] - 0s 9ms/step - loss: -1.5973 - val_loss: -1.6536
# Epoch 52/100
# 15/15 [==============================] - 0s 9ms/step - loss: -1.7868 - val_loss: -1.8214
# Epoch 53/100
# 15/15 [==============================] - 0s 9ms/step - loss: -1.9417 - val_loss: -1.9616
# Epoch 54/100
# 15/15 [==============================] - 0s 8ms/step - loss: -2.0761 - val_loss: -2.0573
# Epoch 55/100
# 15/15 [==============================] - 0s 9ms/step - loss: -2.1209 - val_loss: -2.0081
# Epoch 56/100
# 15/15 [==============================] - 0s 8ms/step - loss: -2.1629 - val_loss: -2.0926
# Epoch 57/100
# 15/15 [==============================] - 0s 9ms/step - loss: -2.1722 - val_loss: -2.0662
# Epoch 58/100
# 15/15 [==============================] - 0s 9ms/step - loss: -2.1947 - val_loss: -2.0764
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1748 - val_loss: -2.1084
# Epoch 60/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.1743 - val_loss: -2.1178
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1943 - val_loss: -2.1303
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.1802 - val_loss: -2.0913
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.2057 - val_loss: -2.1227
# Epoch 64/100
# 15/15 [==============================] - 0s 7ms/step - loss: -2.1902 - val_loss: -2.0925
# Epoch 65/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.1914 - val_loss: -2.0985
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.2422 - val_loss: -2.0864
# Epoch 66: early stopping

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.show()

# %% [markdown]
# ### e)

# %%
t_x_pred = model.predict(x)[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x, mu1, mu2, Sigma1, Sigma2)

# %%
plt.plot(t_x_opt)
plt.plot(t_x_pred)

plt.show()

# %%
plt.plot(t_x_pred[y==1], t_x_opt[y==1], "o", alpha=0.2, markersize=2)
plt.plot(t_x_pred[y==0], t_x_opt[y==0], "o", alpha=0.2, markersize=2)
plt.grid()
plt.show()

# %%
plt.plot(t_x_pred, t_x_opt, "o")
plt.show()

# %%
DV_fun(y, t_x_pred)
# Out:
# 2.0302703668229496

# %%
DV_fun(y, t_x_opt)
# Out:
# 2.3049447052510614

# %%
# new data
n_new = 10000
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n_new)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n_new)
x_new = np.concatenate((x1, x2), axis=0)
y_new = np.concatenate((1.0*np.ones(n_new), 0.0*np.zeros(n_new)))

# %%
t_x_pred = model.predict(x_new)
t_x_pred = t_x_pred[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x_new, mu1, mu2, Sigma1, Sigma2)

# %%
DV_fun(y_new, t_x_pred)
# Out:
# 1.7999280231683876

# %%
DV_fun(y_new, t_x_opt)
# Out:
# 2.278359944867194

# %% [markdown]
# ### f)

# %%
def NWJ_loss(y_true, T_x):
    n1 = tf.math.reduce_sum(y_true)
    n2 = tf.math.reduce_sum(tf.subtract(tf.convert_to_tensor(1.0), y_true))
    first_term = tf.math.reduce_sum(tf.math.multiply(T_x, y_true))/n1
    second_term = tf.math.reduce_sum(tf.math.multiply(tf.math.exp(tf.subtract(T_x, tf.convert_to_tensor(1.0))), tf.subtract(tf.convert_to_tensor(1.0), y_true)))/n2
    return -(first_term - second_term)

def NWJ_fun(y, t):
    return np.mean(t[y == 1]) - np.mean(np.exp(t[y == 0] - 1))

# %%
model_inputs = keras.Input(shape=(5))
layer_out = Dense(64, activation='softplus')(model_inputs)
#layer_out = Dense(125, activation='tanh')(layer_out)
layer_out = Dense(64)(layer_out)
model_outputs = Dense(1)(layer_out)
model = keras.Model(model_inputs, model_outputs)

optimizer = keras.optimizers.SGD(learning_rate=1e-2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=optimizer, loss=NWJ_loss)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
hist = model.fit(x_train, y_train, epochs=100, batch_size=1024, validation_data=(x_test, y_test), callbacks=[es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 23ms/step - loss: 0.0878 - val_loss: -0.0130
# Epoch 2/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.0165 - val_loss: -0.0351
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.0372 - val_loss: -0.0473
# Epoch 4/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0493 - val_loss: -0.0545
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0571 - val_loss: -0.0587
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0621 - val_loss: -0.0621
# Epoch 7/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0657 - val_loss: -0.0644
# Epoch 8/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0691 - val_loss: -0.0664
# Epoch 9/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0706 - val_loss: -0.0680
# Epoch 10/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0731 - val_loss: -0.0698
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0754 - val_loss: -0.0715
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0775 - val_loss: -0.0730
# Epoch 13/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0799 - val_loss: -0.0748
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0809 - val_loss: -0.0767
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0829 - val_loss: -0.0785
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0851 - val_loss: -0.0803
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0871 - val_loss: -0.0816
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0893 - val_loss: -0.0843
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0911 - val_loss: -0.0864
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0934 - val_loss: -0.0885
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0955 - val_loss: -0.0890
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0976 - val_loss: -0.0931
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1005 - val_loss: -0.0955
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1029 - val_loss: -0.0982
# Epoch 25/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1056 - val_loss: -0.1009
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1084 - val_loss: -0.1034
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1112 - val_loss: -0.1067
# Epoch 28/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1144 - val_loss: -0.1092
# Epoch 29/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1173 - val_loss: -0.1130
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1209 - val_loss: -0.1164
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1244 - val_loss: -0.1196
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1281 - val_loss: -0.1241
# Epoch 33/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1321 - val_loss: -0.1281
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1368 - val_loss: -0.1324
# Epoch 35/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1411 - val_loss: -0.1376
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1464 - val_loss: -0.1422
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1514 - val_loss: -0.1483
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1574 - val_loss: -0.1543
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1637 - val_loss: -0.1608
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1706 - val_loss: -0.1678
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1779 - val_loss: -0.1746
# Epoch 42/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1858 - val_loss: -0.1841
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1950 - val_loss: -0.1933
# Epoch 44/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2039 - val_loss: -0.2034
# Epoch 45/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2151 - val_loss: -0.2149
# Epoch 46/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2267 - val_loss: -0.2270
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2399 - val_loss: -0.2411
# Epoch 48/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2545 - val_loss: -0.2556
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2704 - val_loss: -0.2737
# Epoch 50/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2893 - val_loss: -0.2935
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3097 - val_loss: -0.3144
# Epoch 52/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3329 - val_loss: -0.3405
# Epoch 53/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3601 - val_loss: -0.3691
# Epoch 54/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.3905 - val_loss: -0.4023
# Epoch 55/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.4261 - val_loss: -0.4404
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.4653 - val_loss: -0.4814
# Epoch 57/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.5135 - val_loss: -0.5350
# Epoch 58/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.5686 - val_loss: -0.5946
# Epoch 59/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.6333 - val_loss: -0.6639
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.7078 - val_loss: -0.7410
# Epoch 61/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.7971 - val_loss: -0.8384
# Epoch 62/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.9025 - val_loss: -0.9527
# Epoch 63/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.0208 - val_loss: -1.0835
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.1504 - val_loss: -1.2084
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.3185 - val_loss: -1.4040
# Epoch 66/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.3620 - val_loss: -1.5573
# Epoch 67/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.6424 - val_loss: -1.5927
# Epoch 68/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.4842 - val_loss: 1.8528
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.4761 - val_loss: -1.7335
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.8665 - val_loss: -1.9575
# Epoch 71/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.2248 - val_loss: -1.7394
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.4511 - val_loss: -1.9873
# Epoch 73/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.5428 - val_loss: -1.9558
# Epoch 74/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.3761 - val_loss: -1.6297
# Epoch 75/100
# 15/15 [==============================] - 0s 5ms/step - loss: -1.8703 - val_loss: -1.2383
# Epoch 76/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.6443 - val_loss: -1.7535
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.8216 - val_loss: -1.9680
# Epoch 77: early stopping

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.show()

# %% [markdown]
# ### e)

# %%
t_x_pred = model.predict(x)[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x, mu1, mu2, Sigma1, Sigma2)

# %%
plt.plot(t_x_opt)
plt.plot(t_x_pred)

plt.show()

# %%
plt.plot(t_x_pred[y==1], t_x_opt[y==1], "o", alpha=0.2, markersize=2)
plt.plot(t_x_pred[y==0], t_x_opt[y==0], "o", alpha=0.2, markersize=2)
plt.grid()
plt.show()

# %%
plt.plot(t_x_pred, t_x_opt, "o")
plt.show()

# %%
NWJ_fun(y, t_x_pred)
# Out:
# 2.0110586

# %%
NWJ_fun(y, t_x_opt)
# Out:
# 1.8676700902176118

# %%
# new data
n_new = 10000
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n_new)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n_new)
x_new = np.concatenate((x1, x2), axis=0)
y_new = np.concatenate((1.0*np.ones(n_new), 0.0*np.zeros(n_new)))

# %%
t_x_pred = model.predict(x_new)
t_x_pred = t_x_pred[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x_new, mu1, mu2, Sigma1, Sigma2)

# %%
NWJ_fun(y_new, t_x_pred)
# Out:
# 2.0324812

# %%
NWJ_fun(y_new, t_x_opt)
# Out:
# 1.9173311199718448
