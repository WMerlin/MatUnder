# %% [markdown]
# # Mathematical Underpinnings - Lab 7

# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Input, Dense, Lambda, InputLayer, concatenate
from keras.models import Model, Sequential
from keras import backend as K
from keras import metrics
from keras.datasets import mnist
from keras.utils import to_categorical

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Task 1
#
# ### a)

# %%
def KL_mult_normal(mu1, mu2, Sigma1, Sigma2):
    # the formula is here: https://statproofbook.github.io/P/mvn-kl.html
    return (np.dot(mu2-mu1, np.dot(np.linalg.inv(Sigma2), mu2 - mu1)) + np.sum(np.diag(np.dot(np.linalg.inv(Sigma2), Sigma1))) \
        - np.log(np.linalg.det(Sigma1)/np.linalg.det(Sigma2)) - mu1.shape[0])/2

# %%
def T_opt(x, mu1, mu2, Sigma1, Sigma2):
    # compute log(p(x)/q(x)), where p and q are multivariate normal with parameters mu1, Sigma1 and mu2, Sigma2 respectively
    # density of multivariate normal distribution is e.g. here: https://en.wikipedia.org/wiki/Multivariate_normal_distribution
    res = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        ft = -np.log(np.linalg.det(Sigma1))/2 - np.dot(np.dot(np.linalg.inv(Sigma1), (x[i,:] - mu1)), x[i,:] - mu1)/2
        st = np.log(np.linalg.det(Sigma2))/2 + np.dot(np.dot(np.linalg.inv(Sigma2), x[i,:] - mu2), x[i,:] - mu2)/2
        res[i] = ft+st
    return res

# %% [markdown]
# ### b)

# %%
# sample n = 10000 observations out of np.random.multivariate_normal(mu1, Sigma1, size=n)
# and sample n = 10000 observations out of np.random.multivariate_normal(mu2, Sigma2, size=n)
# then concatenate the two matrices (your final x is a matrix 2n x 5)
# then create a vector y that will have n ones and n zeros (of size 2n)

# np.random.seed(123)
n = 10000
mu1 = np.array([1, 1, 1, 0, 0])/5
mu2 = np.array([0, 0, 1, 1, 1])/5
Sigma1 = (np.eye(5)*9 + np.ones((5,5)))/10
Sigma2 = 1.2*np.eye(5) - np.ones((5,5))/5
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n)
x = np.concatenate((x1, x2), axis=0)
y = np.concatenate((1.0*np.ones(n), 0.0*np.zeros(n)))

# %%
def DV_fun(y, t):
    # y - an indicator [y[i]=1 if t[i] corresponds to x sampled from the distribution p, y[i]=0 otherwise]
    # t a vector (of the same length as y) t = log(p(x)/q(x))
    n1 = np.sum(y)
    n2 = np.sum(1 - y)
    return np.sum(t*y)/n1 - np.log(np.sum(np.exp(t)*(1-y))/n2)

# %%
KL_mult_normal(mu1, mu2, Sigma1, Sigma2)
# Out:
# 2.169075737042573

# %%
DV_fun(y, T_opt(x, mu1, mu2, Sigma1, Sigma2))
# Out:
# 2.3476009940389364

# %%
# 18:56

# %% [markdown]
# ### c)

# %%
def DV_loss(y_true, T_x):
    n1 = tf.math.reduce_sum(y_true)
    n2 = tf.math.reduce_sum(tf.subtract(tf.convert_to_tensor(1.0), y_true))
    first_term = tf.math.reduce_sum(tf.math.multiply(T_x, y_true))/n1
    second_term = tf.math.log(tf.math.reduce_sum(tf.math.multiply(tf.math.exp(T_x), tf.subtract(tf.convert_to_tensor(1.0), y_true)))/n2)
    return -(first_term - second_term)

# %% [markdown]
# ### d)

# %%
model_inputs = keras.Input(shape=(5))
layer_out = Dense(64, activation='softplus')(model_inputs)
#layer_out = Dense(125, activation='tanh')(layer_out)
layer_out = Dense(64)(layer_out)
model_outputs = Dense(1)(layer_out)
model = keras.Model(model_inputs, model_outputs)

optimizer = keras.optimizers.SGD(learning_rate=1e-2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=optimizer, loss=DV_loss)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
hist = model.fit(x_train, y_train, epochs=100, batch_size=1024, validation_data=(x_test, y_test), callbacks=[es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 20ms/step - loss: 0.0119 - val_loss: -0.0155
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0200 - val_loss: -0.0351
# Epoch 3/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.0384 - val_loss: -0.0461
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0501 - val_loss: -0.0528
# Epoch 5/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.0575 - val_loss: -0.0571
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0629 - val_loss: -0.0602
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0667 - val_loss: -0.0626
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0698 - val_loss: -0.0648
# Epoch 9/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0728 - val_loss: -0.0669
# Epoch 10/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0750 - val_loss: -0.0689
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0775 - val_loss: -0.0711
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0803 - val_loss: -0.0733
# Epoch 13/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0823 - val_loss: -0.0755
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0851 - val_loss: -0.0778
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0873 - val_loss: -0.0801
# Epoch 16/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.0899 - val_loss: -0.0826
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0926 - val_loss: -0.0852
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0956 - val_loss: -0.0878
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0981 - val_loss: -0.0906
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1009 - val_loss: -0.0935
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1040 - val_loss: -0.0965
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1073 - val_loss: -0.0995
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1105 - val_loss: -0.1030
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1142 - val_loss: -0.1065
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1175 - val_loss: -0.1101
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1217 - val_loss: -0.1140
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1257 - val_loss: -0.1182
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1298 - val_loss: -0.1228
# Epoch 29/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1345 - val_loss: -0.1277
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1394 - val_loss: -0.1329
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1450 - val_loss: -0.1385
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1510 - val_loss: -0.1446
# Epoch 33/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1566 - val_loss: -0.1512
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1640 - val_loss: -0.1584
# Epoch 35/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1715 - val_loss: -0.1662
# Epoch 36/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.1794 - val_loss: -0.1747
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1883 - val_loss: -0.1842
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1983 - val_loss: -0.1944
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2090 - val_loss: -0.2061
# Epoch 40/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2212 - val_loss: -0.2188
# Epoch 41/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2343 - val_loss: -0.2332
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2493 - val_loss: -0.2493
# Epoch 43/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.2665 - val_loss: -0.2675
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2855 - val_loss: -0.2880
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3072 - val_loss: -0.3114
# Epoch 46/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.3321 - val_loss: -0.3380
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3603 - val_loss: -0.3690
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3924 - val_loss: -0.4043
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.4311 - val_loss: -0.4456
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.4754 - val_loss: -0.4937
# Epoch 51/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.5265 - val_loss: -0.5499
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.5875 - val_loss: -0.6170
# Epoch 53/100
# 15/15 [==============================] - 0s 5ms/step - loss: -0.6586 - val_loss: -0.6963
# Epoch 54/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.7457 - val_loss: -0.7910
# Epoch 55/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.8460 - val_loss: -0.9034
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.9684 - val_loss: -1.0377
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.1114 - val_loss: -1.1938
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.2780 - val_loss: -1.3764
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.4696 - val_loss: -1.5795
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.6760 - val_loss: -1.7874
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.8898 - val_loss: -1.9838
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.0791 - val_loss: -2.1389
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.2150 - val_loss: -2.2241
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.3346 - val_loss: -2.2343
# Epoch 65/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.4157 - val_loss: -2.2498
# Epoch 66/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.4549 - val_loss: -2.1896
# Epoch 67/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.4403 - val_loss: -2.0388
# Epoch 68/100
# 15/15 [==============================] - 0s 5ms/step - loss: -2.4575 - val_loss: -2.2236
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.4562 - val_loss: -2.2367
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: -2.4770 - val_loss: -2.1835
# Epoch 70: early stopping

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.show()

# %% [markdown]
# ### e)

# %%
t_x_pred = model.predict(x)[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x, mu1, mu2, Sigma1, Sigma2)

# %%
plt.plot(t_x_opt)
plt.plot(t_x_pred)

plt.show()

# %%
plt.plot(t_x_pred[y==1], t_x_opt[y==1], "o", alpha=0.2, markersize=2)
plt.plot(t_x_pred[y==0], t_x_opt[y==0], "o", alpha=0.2, markersize=2)
plt.grid()
plt.show()

# %%
plt.plot(t_x_pred, t_x_opt, "o")
plt.show()

# %%
DV_fun(y, t_x_pred)
# Out:
# 2.090257100027367

# %%
DV_fun(y, t_x_opt)
# Out:
# 2.3476009940389364

# %%
# new data
n_new = 10000
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n_new)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n_new)
x_new = np.concatenate((x1, x2), axis=0)
y_new = np.concatenate((1.0*np.ones(n_new), 0.0*np.zeros(n_new)))

# %%
t_x_pred = model.predict(x_new)
t_x_pred = t_x_pred[:,0]
# Out:
# 625/625 [==============================] - 1s 1ms/step

# %%
t_x_opt = T_opt(x_new, mu1, mu2, Sigma1, Sigma2)

# %%
DV_fun(y_new, t_x_pred)
# Out:
# 0.9788111566523057

# %%
DV_fun(y_new, t_x_opt)
# Out:
# 2.140264250464021

# %% [markdown]
# ### f)

# %%
def NWJ_fun(y, t):
    return np.mean(t[y==1]) - np.mean(np.exp(t[y==0] - 1))

# %%
def NWJ_loss(y_true, y_pred):
    first = tf.math.reduce_mean(y_pred[y_true==1])
    second = tf.math.reduce_mean(tf.math.exp(y_pred[y_true==0] - 1))
    return - (first - second)

# %%
model_inputs = keras.Input(shape=(5))
layer_out = Dense(64, activation='softplus')(model_inputs)
#layer_out = Dense(125, activation='tanh')(layer_out)
layer_out = Dense(64)(layer_out)
model_outputs = Dense(1)(layer_out)
model = keras.Model(model_inputs, model_outputs)

optimizer = keras.optimizers.SGD(learning_rate=1e-2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=optimizer, loss=NWJ_loss)

hist = model.fit(x_train, y_train, epochs=100, batch_size=1024, validation_data=(x_test, y_test), callbacks=[es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 19ms/step - loss: 0.0922 - val_loss: 0.0251
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: -0.0052
# Epoch 3/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0183 - val_loss: -0.0237
# Epoch 4/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0349 - val_loss: -0.0361
# Epoch 5/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0463 - val_loss: -0.0446
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0545 - val_loss: -0.0509
# Epoch 7/100
# 15/15 [==============================] - 0s 9ms/step - loss: -0.0606 - val_loss: -0.0556
# Epoch 8/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0655 - val_loss: -0.0595
# Epoch 9/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0694 - val_loss: -0.0627
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0729 - val_loss: -0.0655
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0761 - val_loss: -0.0685
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0791 - val_loss: -0.0716
# Epoch 13/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.0819 - val_loss: -0.0744
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0849 - val_loss: -0.0771
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0878 - val_loss: -0.0801
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.0908 - val_loss: -0.0824
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0939 - val_loss: -0.0855
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.0967 - val_loss: -0.0892
# Epoch 19/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1006 - val_loss: -0.0921
# Epoch 20/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1036 - val_loss: -0.0959
# Epoch 21/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1077 - val_loss: -0.0996
# Epoch 22/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1112 - val_loss: -0.1033
# Epoch 23/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1155 - val_loss: -0.1075
# Epoch 24/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.1196 - val_loss: -0.1120
# Epoch 25/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1243 - val_loss: -0.1167
# Epoch 26/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1291 - val_loss: -0.1216
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1347 - val_loss: -0.1271
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1399 - val_loss: -0.1329
# Epoch 29/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1461 - val_loss: -0.1393
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1524 - val_loss: -0.1456
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1601 - val_loss: -0.1533
# Epoch 32/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1678 - val_loss: -0.1619
# Epoch 33/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1761 - val_loss: -0.1710
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.1860 - val_loss: -0.1807
# Epoch 35/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.1966 - val_loss: -0.1921
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2080 - val_loss: -0.2039
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2212 - val_loss: -0.2183
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2360 - val_loss: -0.2335
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2515 - val_loss: -0.2517
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2705 - val_loss: -0.2714
# Epoch 41/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.2919 - val_loss: -0.2940
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.3158 - val_loss: -0.3206
# Epoch 43/100
# 15/15 [==============================] - 0s 8ms/step - loss: -0.3434 - val_loss: -0.3505
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.3755 - val_loss: -0.3854
# Epoch 45/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.4129 - val_loss: -0.4257
# Epoch 46/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.4562 - val_loss: -0.4723
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.5076 - val_loss: -0.5286
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: -0.5665 - val_loss: -0.5948
# Epoch 49/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.6370 - val_loss: -0.6723
# Epoch 50/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.7209 - val_loss: -0.7639
# Epoch 51/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.8194 - val_loss: -0.8699
# Epoch 52/100
# 15/15 [==============================] - 0s 7ms/step - loss: -0.9360 - val_loss: -1.0039
# Epoch 53/100
# 15/15 [==============================] - 0s 7ms/step - loss: -1.0745 - val_loss: -1.1541
# Epoch 54/100
# 15/15 [==============================] - 0s 7ms/step - loss: -1.2348 - val_loss: -1.2938
# Epoch 55/100
# 15/15 [==============================] - 0s 7ms/step - loss: -1.3803 - val_loss: -1.4001
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.5088 - val_loss: -1.6132
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.5833 - val_loss: -1.7330
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.6052 - val_loss: -1.9235
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.7796 - val_loss: -2.0449
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.9708 - val_loss: -2.1472
# Epoch 61/100
# 15/15 [==============================] - 0s 8ms/step - loss: -1.7395 - val_loss: -1.4732
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.5069 - val_loss: 3.0056
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.2449 - val_loss: -0.5720
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.8780 - val_loss: -1.3741
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: -1.7085 - val_loss: -1.1700
# Epoch 65: early stopping

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.show()

# %%
t_x_pred_nwj = model.predict(x)[:,0]
t_x_opt_nwj = T_opt(x, mu1, mu2, Sigma1, Sigma2)

plt.plot(t_x_opt_nwj)
plt.plot(t_x_pred_nwj)
plt.show()
# Out:
# 625/625 [==============================] - 1s 2ms/step

# %%
plt.plot(t_x_pred_nwj, t_x_opt_nwj, "o")
plt.show()

# %%
print(f"NWJ: {NWJ_fun(y, t_x_pred_nwj)}, DV: {DV_fun(y, t_x_pred)}")
# Out:
# NWJ: 1.9170544147491455, DV: 0.9788111566523057

# %%
print(f"NWJ: {NWJ_fun(y, t_x_opt_nwj)}, DV: {DV_fun(y, t_x_opt)}")
# Out:
# NWJ: 1.8663055322682602, DV: 2.140264250464021

# %%
n_new = 10000
x1 = np.random.multivariate_normal(mu1, Sigma1, size=n_new)
x2 = np.random.multivariate_normal(mu2, Sigma2, size=n_new)
x_new = np.concatenate((x1, x2), axis=0)
y_new = np.concatenate((1.0*np.ones(n_new), 0.0*np.zeros(n_new)))

t_x_pred_new = model.predict(x_new)
t_x_pred_new = t_x_pred_new[:,0]

t_x_opt_new = T_opt(x_new, mu1, mu2, Sigma1, Sigma2)
# Out:
# 625/625 [==============================] - 1s 2ms/step

# %%
print(f"NWJ: {NWJ_fun(y_new, t_x_pred_new)}, DV: {DV_fun(y_new, t_x_pred_new)}")
# Out:
# NWJ: 0.8851001262664795, DV: 1.7555315288529267

# %%
print(f"NWJ: {NWJ_fun(y_new, t_x_opt_new)}, DV: {DV_fun(y_new, t_x_opt_new)}")
# Out:
# NWJ: 1.73588448662049, DV: 2.0879569921302545
